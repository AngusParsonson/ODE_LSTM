# %%
import torch
print("hello")

# %load_ext tensorboard
# %tensorboard --logdir=tb_logs
# Out:
# hello
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-74290a70b74d> in <module>
#       1 import torch
#       2 print("hello")
# ----> 3 print(tempfile.gettempdir())
#       4 get_ipython().run_line_magic('load_ext', 'tensorboard')
#       5 get_ipython().run_line_magic('tensorboard', '--logdir=tb_logs')
#
# NameError: name 'tempfile' is not defined
